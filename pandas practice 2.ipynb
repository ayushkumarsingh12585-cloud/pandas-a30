# %%
print("hello")
# Out:
# hello

# %%
import pandas as pd 
df=pd.DataFrame({
    "name":["amit","neha","rahul"],
    "age":[22,23,21]
        }
)
print(df)
# Out:
#     name  age
# 0   amit   22
# 1   neha   23
# 2  rahul   21

# %%
import pandas as pd 
df=pd.DataFrame({
    "name":["a","b","c"],
    "marks":[87,89,90]
    },index=["student1","student2","student3"]
    )
print(df)
# Out:
#          name  marks
# student1    a     87
# student2    b     89
# student3    c     90

# %%
print(df.shape)
# Out:
# (3, 2)

# %%
print(df.columns)
# Out:
# Index(['name', 'marks'], dtype='object')

# %%
print(df.loc["student2"])
# Out:
# name      b
# marks    89
# Name: student2, dtype: object

# %%
print(df.iloc[1])
# Out:
# name      b
# marks    89
# Name: student2, dtype: object

# %%
print(df["marks"])
# Out:
# student1    87
# student2    89
# student3    90
# Name: marks, dtype: int64

# %%
df["city"]=["jaipur","delhi","mumbai"]
print(df)
# Out:
#          name  marks    city
# student1    a     87  jaipur
# student2    b     89   delhi
# student3    c     90  mumbai

# %%
print(df[df["marks"]>88])
# Out:
#          name  marks    city
# student2    b     89   delhi
# student3    c     90  mumbai

# %%
print(df.head(2))
# Out:
#          name  marks    city
# student1    a     87  jaipur
# student2    b     89   delhi

# %%
print(df.tail(2))
# Out:
#          name  marks    city
# student2    b     89   delhi
# student3    c     90  mumbai

# %%
import pandas as pd

df = pd.DataFrame({
    "name": ["amit","neha","rahul","priya","ayush"],
    "age": [22,24,21,23,22],
    "marks": [85,92,78,88,95],
    "city": ["jaipur","delhi","mumbai","jaipur","delhi"]
})

print(df)
# Out:
#     name  age  marks    city
# 0   amit   22     85  jaipur
# 1   neha   24     92   delhi
# 2  rahul   21     78  mumbai
# 3  priya   23     88  jaipur
# 4  ayush   22     95   delhi

# %%
print(df[["name","marks"]])
# Out:
#     name  marks
# 0   amit     85
# 1   neha     92
# 2  rahul     78
# 3  priya     88
# 4  ayush     95

# %%
print(df.iloc[1:4])
# Out:
#     name  age  marks    city
# 1   neha   24     92   delhi
# 2  rahul   21     78  mumbai
# 3  priya   23     88  jaipur

# %%
print(df.loc[0])
# Out:
# name       amit
# age          22
# marks        85
# city     jaipur
# Name: 0, dtype: object

# %%
print(df.iloc[0])
# Out:
# name       amit
# age          22
# marks        85
# city     jaipur
# Name: 0, dtype: object

# %%
print(df[df["age"]==22])
# Out:
#     name  age  marks    city
# 0   amit   22     85  jaipur
# 4  ayush   22     95   delhi

# %%
print(df["marks"].mean())
# Out:
# 87.6

# %%
print(df["marks"].max())
# Out:
# 95

# %%
print(df.sort_values("marks"))
# Out:
#     name  age  marks    city
# 2  rahul   21     78  mumbai
# 0   amit   22     85  jaipur
# 3  priya   23     88  jaipur
# 1   neha   24     92   delhi
# 4  ayush   22     95   delhi

# %%
print(df["city"].value_counts())
# Out:
# city
# jaipur    2
# delhi     2
# mumbai    1
# Name: count, dtype: int64
